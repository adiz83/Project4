# %% [markdown]
# # Merging file 1 and file 2

# %%
import pandas as pd

# %%
df1=pd.read_csv("file1.csv")
df2=pd.read_csv("file_2.csv")

# %%
print(df1)
# Out:
#                                File  Positive Score  Negative Score  \
# 0   blackassign_blackassign0001.txt              31               7
# 1   blackassign_blackassign0002.txt              58              30
# 2   blackassign_blackassign0003.txt              41              24
# 3   blackassign_blackassign0004.txt              42              75
# 4   blackassign_blackassign0005.txt              23               9
# ..                              ...             ...             ...
# 93  blackassign_blackassign0096.txt              31              55
# 94  blackassign_blackassign0097.txt              27              36
# 95  blackassign_blackassign0098.txt               6               1
# 96  blackassign_blackassign0099.txt              16               4
# 97  blackassign_blackassign0100.txt              34              56
#
#     Polarity Score  Subjectivity Score
# 0         0.631579            0.064189
# 1         0.318182            0.113695
# ...

# %%
df2['Average Number Of Words Per Sentence'] = df2['Average Sentence Length'] 
print(df2.columns)
# Out:
# Index(['File', 'Average Sentence Length', 'Percentage of Complex Words',
#        'Fog Index', 'Count of Complex Words', 'Syllable Count Per Word',
#        'Personal Pronoun Counts', 'Average Word Length', 'Cleaned Word Count',
#        'Average Number Of Words Per Sentence'],
#       dtype='object')

# %%
df1
# Out:
#                                File  Positive Score  Negative Score  \
# 0   blackassign_blackassign0001.txt              31               7
# 1   blackassign_blackassign0002.txt              58              30
# 2   blackassign_blackassign0003.txt              41              24
# 3   blackassign_blackassign0004.txt              42              75
# 4   blackassign_blackassign0005.txt              23               9
# ..                              ...             ...             ...
# 93  blackassign_blackassign0096.txt              31              55
# 94  blackassign_blackassign0097.txt              27              36
# 95  blackassign_blackassign0098.txt               6               1
# 96  blackassign_blackassign0099.txt              16               4
# 97  blackassign_blackassign0100.txt              34              56
#
#     Polarity Score  Subjectivity Score
# 0         0.631579            0.064189
# 1         0.318182            0.113695
# ...

# %%
column_mapping_df1 = {
    'File': 'URL_ID',
    'Positive Score': 'POSITIVE SCORE',
    'Negative Score': 'NEGATIVE SCORE',
    'Polarity Score': 'POLARITY SCORE',
    'Subjectivity Score': 'SUBJECTIVITY SCORE',
}

# %%
df1 = df1.rename(columns=column_mapping_df1)

# %%
column_mapping_df2 = {
    'File': 'URL_ID',
    'Average Sentence Length': 'AVG SENTENCE LENGTH',
    'Percentage of Complex Words': 'PERCENTAGE OF COMPLEX WORDS',
    'Fog Index': 'FOG INDEX',
    'Count of Complex Words': 'COMPLEX WORD COUNT',
    'Syllable Count Per Word': 'SYLLABLE PER WORD',
    'Personal Pronoun Counts': 'PERSONAL PRONOUNS',
    'Average Word Length': 'AVG WORD LENGTH',
    'Cleaned Word Count': 'WORD COUNT',
    'Average Number Of Words Per Sentence': 'AVG NUMBER OF WORDS PER SENTENCE',
}

# %%
df2 = df2.rename(columns=column_mapping_df2)
print(df2)
# Out:
#                              URL_ID  AVG SENTENCE LENGTH  \
# 0   blackassign_blackassign0001.txt            22.323944
# 1   blackassign_blackassign0002.txt            23.728395
# 2   blackassign_blackassign0003.txt            24.032787
# 3   blackassign_blackassign0004.txt            26.035714
# 4   blackassign_blackassign0005.txt            22.977273
# ..                              ...                  ...
# 93  blackassign_blackassign0096.txt            27.018519
# 94  blackassign_blackassign0097.txt            33.767442
# 95  blackassign_blackassign0098.txt            46.777778
# 96  blackassign_blackassign0099.txt            25.848485
# 97  blackassign_blackassign0100.txt            36.742857
#
#     PERCENTAGE OF COMPLEX WORDS  FOG INDEX  COMPLEX WORD COUNT  \
# 0                     20.694006  17.207180                 328
# 1                     27.627471  20.542347                 531
# 2                     32.810368  22.737262                 481
# ...

# %%
print(df1)
print(df2)
# Out:
#                              URL_ID  POSITIVE SCORE  NEGATIVE SCORE  \
# 0   blackassign_blackassign0001.txt              31               7
# 1   blackassign_blackassign0002.txt              58              30
# 2   blackassign_blackassign0003.txt              41              24
# 3   blackassign_blackassign0004.txt              42              75
# 4   blackassign_blackassign0005.txt              23               9
# ..                              ...             ...             ...
# 93  blackassign_blackassign0096.txt              31              55
# 94  blackassign_blackassign0097.txt              27              36
# 95  blackassign_blackassign0098.txt               6               1
# 96  blackassign_blackassign0099.txt              16               4
# 97  blackassign_blackassign0100.txt              34              56
#
#     POLARITY SCORE  SUBJECTIVITY SCORE
# 0         0.631579            0.064189
# 1         0.318182            0.113695
# ...

# %%
merged_df = pd.merge(df1, df2, on='URL_ID', how='inner')

desired_columns_order = ['URL_ID', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE', 
                          'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH', 'PERCENTAGE OF COMPLEX WORDS',
                          'FOG INDEX', 'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT',
                          'WORD COUNT', 'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH']

merged_df = merged_df[desired_columns_order]
merged_df['URL_ID'] = merged_df['URL_ID'].str.replace('.txt', '')
merged_df['URL_ID'] = merged_df['URL_ID'].str.replace('blackassign_', '')
print(merged_df)
# Out:
#              URL_ID  POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  \
# 0   blackassign0001              31               7        0.631579
# 1   blackassign0002              58              30        0.318182
# 2   blackassign0003              41              24        0.261538
# 3   blackassign0004              42              75       -0.282051
# 4   blackassign0005              23               9        0.437500
# ..              ...             ...             ...             ...
# 93  blackassign0096              31              55       -0.279070
# 94  blackassign0097              27              36       -0.142857
# 95  blackassign0098               6               1        0.714286
# 96  blackassign0099              16               4        0.600000
# 97  blackassign0100              34              56       -0.244444
#
#     SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  \
# 0             0.064189            22.323944                    20.694006
# ...

# %%
input_df = pd.read_excel('Input.xlsx') 
print(input_df)
# Out:
#              URL_ID                                                URL
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
# [100 rows x 2 columns]

# %%
final_merged_df = pd.merge(merged_df, input_df, left_on='URL_ID', right_on='URL_ID', how='inner')
desired_columns_order = ['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE', 
                          'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH', 'PERCENTAGE OF COMPLEX WORDS',
                          'FOG INDEX', 'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT',
                          'WORD COUNT', 'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH']


final_merged_df = final_merged_df[desired_columns_order]

# %%
print(final_merged_df)
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 93  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 94  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 95  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 96  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 97  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# ...

# %%
final_merged_df.to_excel('Analysis_Output.xlsx', index=False)
